# %% [markdown]
# ## Import libraries

# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and preprocess data

# %%
train_data = np.load('dataset/Trousers & Jeans - Female - train.npz')
validation_data = np.load('dataset/Trousers & Jeans - Female - validation.npz')
test_data = np.load('dataset/Trousers & Jeans - Female - test.npz')

# %%
np.unique(train_data)
# Out:
# array(['images', 'labels'], dtype='<U6')

# %%
images_train, labels_train = train_data['images'], train_data['labels']
images_val, labels_val = validation_data['images'], validation_data['labels']
images_test, labels_test = test_data['images'], test_data['labels']

# %%
np.unique(labels_train)
# Out:
# array([0, 1])

# %%
images_train.shape
# Out:
# (2002, 120, 90, 3)

# %%
labels_train.shape
# Out:
# (2002,)

# %%
images_validation.shape
# Out:
# (250, 120, 90, 3)

# %%
labels_validation.shape
# Out:
# (250,)

# %%
images_test.shape
# Out:
# (250, 120, 90, 3)

# %%
labels_test.shape
# Out:
# (250,)

# %%
# standardize 
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %% [markdown]
# ## Create model

# %% [markdown]
# ### Define some hyperparameters

# %%
EPOCHS = 15
BATCH_SIZE = 64

# %%
HP_KERNEL_SIZE_1 = hp.HParam('kernel size 1', hp.Discrete([3,7]))
HP_KERNEL_SIZE_2 = hp.HParam('kernel size 2', hp.Discrete([3,5]))
HP_KERNEL_NUM = hp.HParam('kernel num', hp.Discrete([32,64,128]))
HP_DENSE_SIZE = hp.HParam('dense size', hp.Discrete([256,512,1024]))

METRIC = 'accuracy'

with tf.summary.create_file_writer(r'Logs/Model 1 (Trousers&Jeans_Female)/hparam_tuning').as_default():
    hp.hparams_config(
        hparams = [HP_KERNEL_SIZE_1,HP_KERNEL_SIZE_2,HP_KERNEL_NUM,HP_DENSE_SIZE],
        metrics = [hp.Metric(METRIC, display_name = 'accuracy')]
    )

# %% [markdown]
# ### Model architecture

# %%
def train_test_model(hparams, session_num):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_KERNEL_NUM], hparams[HP_KERNEL_SIZE_1], activation = 'relu', input_shape = (120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_KERNEL_NUM], hparams[HP_KERNEL_SIZE_2], activation = 'relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
    ])
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
    model.compile(optimizer = 'adam', loss = loss_fn, metrics = ['accuracy'])
    
    log_dir = "Logs\\Model 1 (Trousers&Jeans_Female)\\fit\\" + f"run-{session_num}"
    
    # functions for creating confusion matrix
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
        cm (array, shape = [n, n]): a confusion matrix of integer classes
        class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

        return figure

    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""

        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')

        # Closing the figure prevents it from being displayed directly inside the notebook.
        plt.close(figure)

        buf.seek(0)

        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)

        # Add the batch dimension
        image = tf.expand_dims(image, 0)

        return image

    # Define a file writer variable for logging purposes
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')

    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)

        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=['Trousers', 'Jeans'])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
            
    # callbacks
    early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2, restore_best_weights = True)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end = log_confusion_matrix)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, profile_batch = 0)
    
    model.fit(images_train,
              labels_train,
              epochs = EPOCHS,
              batch_size = BATCH_SIZE,
              callbacks = [tensorboard_callback, cm_callback, early_stopping],
              validation_data = (images_val, labels_val),
              verbose = 1)
    
    _, accuracy = model.evaluate(images_val, labels_val)
    
    model.save(r'saved_models\Model 1 (Trousers&Jeans_Female)\Run-{}'.format(session_num))
    
    return accuracy

# %%
def run(log_dir, hparams, session_num):
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC,accuracy,step=1)

# %%
session_num = 1
for kernel_size_1 in HP_KERNEL_SIZE_1.domain.values:
    for kernel_num in HP_KERNEL_NUM.domain.values:
        for kernel_size_2 in HP_KERNEL_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:
                hparams = {
                    HP_KERNEL_SIZE_1 : kernel_size_1,
                    HP_KERNEL_SIZE_2 : kernel_size_2,
                    HP_KERNEL_NUM : kernel_num,
                    HP_DENSE_SIZE : dense_size
                }
                run_name = f'run-{session_num}'
                print('--- Starting Trial:',run_name)
                print({h.name: hparams[h] for h in hparams})
                run("Logs/Model 1 (Trousers&Jeans_Female)/hparam_tuning/" + run_name, hparams, session_num)

                session_num += 1
# Out:
# --- Starting Trial: run-1
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 12s 380ms/step - loss: 0.8185 - accuracy: 0.6828 - val_loss: 0.5150 - val_accuracy: 0.7880
# Epoch 2/15
# 32/32 [==============================] - 11s 356ms/step - loss: 0.4774 - accuracy: 0.7577 - val_loss: 0.5367 - val_accuracy: 0.7040
# Epoch 3/15
# 32/32 [==============================] - 10s 320ms/step - loss: 0.4340 - accuracy: 0.7792 - val_loss: 0.4212 - val_accuracy: 0.8040
# Epoch 4/15
# 32/32 [==============================] - 10s 314ms/step - loss: 0.4065 - accuracy: 0.7977 - val_loss: 0.4342 - val_accuracy: 0.8120
# Epoch 5/15
# 32/32 [==============================] - 10s 309ms/step - loss: 0.3868 - accuracy: 0.8137 - val_loss: 0.8314 - val_accuracy: 0.7040
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4212 - accuracy: 0.8040
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\Python3-TF2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\Python3-TF2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-1\assets
# --- Starting Trial: run-2
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 11s 351ms/step - loss: 1.0514 - accuracy: 0.6139 - val_loss: 0.5818 - val_accuracy: 0.6920
# Epoch 2/15
# 32/32 [==============================] - 11s 349ms/step - loss: 0.5308 - accuracy: 0.7218 - val_loss: 0.6435 - val_accuracy: 0.6760
# Epoch 3/15
# 32/32 [==============================] - 11s 348ms/step - loss: 0.4712 - accuracy: 0.7727 - val_loss: 0.4682 - val_accuracy: 0.8040
# Epoch 4/15
# 32/32 [==============================] - 12s 360ms/step - loss: 0.4317 - accuracy: 0.7862 - val_loss: 0.4632 - val_accuracy: 0.7440
# Epoch 5/15
# 32/32 [==============================] - 11s 345ms/step - loss: 0.4140 - accuracy: 0.8007 - val_loss: 0.4528 - val_accuracy: 0.7880
# Epoch 6/15
# 32/32 [==============================] - 11s 344ms/step - loss: 0.3760 - accuracy: 0.8142 - val_loss: 0.4446 - val_accuracy: 0.8040
# Epoch 7/15
# 32/32 [==============================] - 12s 365ms/step - loss: 0.3370 - accuracy: 0.8362 - val_loss: 0.3836 - val_accuracy: 0.8160
# Epoch 8/15
# 32/32 [==============================] - 11s 345ms/step - loss: 0.3060 - accuracy: 0.8626 - val_loss: 0.3960 - val_accuracy: 0.8120
# Epoch 9/15
# 32/32 [==============================] - 11s 347ms/step - loss: 0.3123 - accuracy: 0.8531 - val_loss: 0.3807 - val_accuracy: 0.8240
# Epoch 10/15
# 32/32 [==============================] - 11s 353ms/step - loss: 0.2493 - accuracy: 0.8981 - val_loss: 0.3857 - val_accuracy: 0.8320
# Epoch 11/15
# 32/32 [==============================] - 11s 344ms/step - loss: 0.3085 - accuracy: 0.8621 - val_loss: 0.3750 - val_accuracy: 0.8360
# Epoch 12/15
# 32/32 [==============================] - 11s 345ms/step - loss: 0.2398 - accuracy: 0.8966 - val_loss: 0.3927 - val_accuracy: 0.8400
# Epoch 13/15
# 32/32 [==============================] - 11s 347ms/step - loss: 0.3177 - accuracy: 0.8651 - val_loss: 0.4284 - val_accuracy: 0.8040
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3750 - accuracy: 0.8360
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-2\assets
# --- Starting Trial: run-3
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 13s 402ms/step - loss: 1.2328 - accuracy: 0.6439 - val_loss: 0.5348 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 [==============================] - 13s 400ms/step - loss: 0.4913 - accuracy: 0.7582 - val_loss: 0.4666 - val_accuracy: 0.7840
# Epoch 3/15
# 32/32 [==============================] - 15s 455ms/step - loss: 0.4539 - accuracy: 0.7822 - val_loss: 0.4763 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 [==============================] - 15s 467ms/step - loss: 0.4014 - accuracy: 0.7962 - val_loss: 0.4509 - val_accuracy: 0.8080
# Epoch 5/15
# 32/32 [==============================] - 14s 427ms/step - loss: 0.3797 - accuracy: 0.8107 - val_loss: 0.4214 - val_accuracy: 0.8080
# Epoch 6/15
# 32/32 [==============================] - 14s 424ms/step - loss: 0.3511 - accuracy: 0.8267 - val_loss: 0.4579 - val_accuracy: 0.7960
# Epoch 7/15
# 32/32 [==============================] - 14s 444ms/step - loss: 0.3462 - accuracy: 0.8352 - val_loss: 0.4076 - val_accuracy: 0.7800
# Epoch 8/15
# 32/32 [==============================] - 13s 399ms/step - loss: 0.3006 - accuracy: 0.8616 - val_loss: 0.3988 - val_accuracy: 0.8040
# Epoch 9/15
# 32/32 [==============================] - 12s 380ms/step - loss: 0.2906 - accuracy: 0.8601 - val_loss: 0.4041 - val_accuracy: 0.8120
# Epoch 10/15
# 32/32 [==============================] - 12s 364ms/step - loss: 0.2959 - accuracy: 0.8621 - val_loss: 0.4140 - val_accuracy: 0.8120
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3988 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-3\assets
# --- Starting Trial: run-4
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 14s 437ms/step - loss: 0.8709 - accuracy: 0.5125 - val_loss: 0.6932 - val_accuracy: 0.4920
# Epoch 2/15
# 32/32 [==============================] - 14s 429ms/step - loss: 0.6633 - accuracy: 0.5759 - val_loss: 0.6658 - val_accuracy: 0.6120
# Epoch 3/15
# 32/32 [==============================] - 14s 425ms/step - loss: 0.5817 - accuracy: 0.7058 - val_loss: 0.5706 - val_accuracy: 0.7160
# Epoch 4/15
# 32/32 [==============================] - 14s 433ms/step - loss: 0.5242 - accuracy: 0.7408 - val_loss: 0.5138 - val_accuracy: 0.7640
# Epoch 5/15
# 32/32 [==============================] - 14s 431ms/step - loss: 0.5105 - accuracy: 0.7493 - val_loss: 0.5197 - val_accuracy: 0.7680
# Epoch 6/15
# 32/32 [==============================] - 14s 442ms/step - loss: 0.4769 - accuracy: 0.7552 - val_loss: 0.5179 - val_accuracy: 0.7360
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5138 - accuracy: 0.7640
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-4\assets
# --- Starting Trial: run-5
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 15s 465ms/step - loss: 0.9316 - accuracy: 0.5894 - val_loss: 0.5764 - val_accuracy: 0.7240
# Epoch 2/15
# 32/32 [==============================] - 15s 468ms/step - loss: 0.5268 - accuracy: 0.7378 - val_loss: 0.5280 - val_accuracy: 0.7240
# Epoch 3/15
# 32/32 [==============================] - 15s 461ms/step - loss: 0.4869 - accuracy: 0.7547 - val_loss: 0.4816 - val_accuracy: 0.7400
# Epoch 4/15
# 32/32 [==============================] - 15s 460ms/step - loss: 0.4462 - accuracy: 0.7637 - val_loss: 0.4849 - val_accuracy: 0.7680
# Epoch 5/15
# 32/32 [==============================] - 15s 464ms/step - loss: 0.4298 - accuracy: 0.7887 - val_loss: 0.4628 - val_accuracy: 0.7880
# Epoch 6/15
# 32/32 [==============================] - 15s 468ms/step - loss: 0.4097 - accuracy: 0.7882 - val_loss: 0.4531 - val_accuracy: 0.7920
# Epoch 7/15
# 32/32 [==============================] - 17s 546ms/step - loss: 0.4012 - accuracy: 0.7957 - val_loss: 0.4461 - val_accuracy: 0.7920
# Epoch 8/15
# 32/32 [==============================] - 16s 499ms/step - loss: 0.3885 - accuracy: 0.8077 - val_loss: 0.4384 - val_accuracy: 0.7800
# Epoch 9/15
# 32/32 [==============================] - 16s 493ms/step - loss: 0.3745 - accuracy: 0.8062 - val_loss: 0.4443 - val_accuracy: 0.7480
# Epoch 10/15
# 32/32 [==============================] - 16s 495ms/step - loss: 0.3574 - accuracy: 0.8267 - val_loss: 0.4497 - val_accuracy: 0.7960
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4384 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-5\assets
# --- Starting Trial: run-6
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 18s 548ms/step - loss: 1.0699 - accuracy: 0.6613 - val_loss: 0.6781 - val_accuracy: 0.6560
# Epoch 2/15
# 32/32 [==============================] - 18s 549ms/step - loss: 0.4986 - accuracy: 0.7582 - val_loss: 0.4929 - val_accuracy: 0.7440
# Epoch 3/15
# 32/32 [==============================] - 17s 536ms/step - loss: 0.4594 - accuracy: 0.7712 - val_loss: 0.4518 - val_accuracy: 0.7680
# Epoch 4/15
# 32/32 [==============================] - 17s 537ms/step - loss: 0.4494 - accuracy: 0.7717 - val_loss: 0.4507 - val_accuracy: 0.7840
# Epoch 5/15
# 32/32 [==============================] - 19s 585ms/step - loss: 0.4249 - accuracy: 0.7847 - val_loss: 0.4278 - val_accuracy: 0.7920
# Epoch 6/15
# 32/32 [==============================] - 19s 598ms/step - loss: 0.3874 - accuracy: 0.8077 - val_loss: 0.5164 - val_accuracy: 0.7680
# Epoch 7/15
# 32/32 [==============================] - 18s 566ms/step - loss: 0.3910 - accuracy: 0.8017 - val_loss: 0.4424 - val_accuracy: 0.7680
# 8/8 [==============================] - 0s 57ms/step - loss: 0.4278 - accuracy: 0.7920
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-6\assets
# --- Starting Trial: run-7
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 24s 739ms/step - loss: 0.9637 - accuracy: 0.5679 - val_loss: 0.9608 - val_accuracy: 0.5160
# Epoch 2/15
# 32/32 [==============================] - 23s 704ms/step - loss: 0.5516 - accuracy: 0.7243 - val_loss: 0.5200 - val_accuracy: 0.7440
# Epoch 3/15
# 32/32 [==============================] - 23s 705ms/step - loss: 0.4745 - accuracy: 0.7547 - val_loss: 0.5219 - val_accuracy: 0.7560
# Epoch 4/15
# 32/32 [==============================] - 21s 645ms/step - loss: 0.4217 - accuracy: 0.7922 - val_loss: 0.4437 - val_accuracy: 0.7600
# Epoch 5/15
# 32/32 [==============================] - 20s 634ms/step - loss: 0.3934 - accuracy: 0.8022 - val_loss: 0.4519 - val_accuracy: 0.7520
# Epoch 6/15
# 32/32 [==============================] - 20s 640ms/step - loss: 0.3591 - accuracy: 0.8227 - val_loss: 0.4635 - val_accuracy: 0.7640
# 8/8 [==============================] - 1s 70ms/step - loss: 0.4437 - accuracy: 0.7600
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-7\assets
# --- Starting Trial: run-8
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 26s 803ms/step - loss: 1.3277 - accuracy: 0.6369 - val_loss: 0.5180 - val_accuracy: 0.7800
# Epoch 2/15
# 32/32 [==============================] - 23s 710ms/step - loss: 0.4793 - accuracy: 0.7707 - val_loss: 0.4832 - val_accuracy: 0.7720
# Epoch 3/15
# 32/32 [==============================] - 23s 733ms/step - loss: 0.4426 - accuracy: 0.7847 - val_loss: 0.4474 - val_accuracy: 0.8040
# Epoch 4/15
# 32/32 [==============================] - 22s 701ms/step - loss: 0.4193 - accuracy: 0.7897 - val_loss: 0.4540 - val_accuracy: 0.7440
# Epoch 5/15
# 32/32 [==============================] - 22s 697ms/step - loss: 0.4027 - accuracy: 0.8142 - val_loss: 0.4930 - val_accuracy: 0.7320
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4474 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-8\assets
# --- Starting Trial: run-9
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 26s 814ms/step - loss: 1.8763 - accuracy: 0.6054 - val_loss: 0.5989 - val_accuracy: 0.6560
# Epoch 2/15
# 32/32 [==============================] - 26s 804ms/step - loss: 0.5163 - accuracy: 0.7328 - val_loss: 0.4905 - val_accuracy: 0.7400
# Epoch 3/15
# 32/32 [==============================] - 26s 806ms/step - loss: 0.4547 - accuracy: 0.7587 - val_loss: 0.5003 - val_accuracy: 0.7160
# Epoch 4/15
# 32/32 [==============================] - 26s 805ms/step - loss: 0.4248 - accuracy: 0.7827 - val_loss: 0.4396 - val_accuracy: 0.7480
# Epoch 5/15
# 32/32 [==============================] - 26s 799ms/step - loss: 0.3939 - accuracy: 0.8002 - val_loss: 0.4778 - val_accuracy: 0.7560
# Epoch 6/15
# 32/32 [==============================] - 26s 817ms/step - loss: 0.3749 - accuracy: 0.8017 - val_loss: 0.4964 - val_accuracy: 0.7680
# 8/8 [==============================] - 1s 84ms/step - loss: 0.4396 - accuracy: 0.7480
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-9\assets
# --- Starting Trial: run-10
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.9447 - accuracy: 0.6324 - val_loss: 0.6014 - val_accuracy: 0.6760
# Epoch 2/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.4900 - accuracy: 0.7368 - val_loss: 0.4884 - val_accuracy: 0.7440
# Epoch 3/15
# 32/32 [==============================] - 31s 978ms/step - loss: 0.4498 - accuracy: 0.7657 - val_loss: 0.4913 - val_accuracy: 0.7880
# Epoch 4/15
# 32/32 [==============================] - 31s 979ms/step - loss: 0.4753 - accuracy: 0.7592 - val_loss: 0.4890 - val_accuracy: 0.7680
# 8/8 [==============================] - 1s 106ms/step - loss: 0.4884 - accuracy: 0.7440
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-10\assets
# --- Starting Trial: run-11
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 33s 1s/step - loss: 1.2007 - accuracy: 0.6234 - val_loss: 0.5280 - val_accuracy: 0.7760
# Epoch 2/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.5044 - accuracy: 0.7483 - val_loss: 0.5351 - val_accuracy: 0.7160
# Epoch 3/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.4756 - accuracy: 0.7587 - val_loss: 0.4690 - val_accuracy: 0.7600
# Epoch 4/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.4298 - accuracy: 0.7902 - val_loss: 0.5172 - val_accuracy: 0.7400
# Epoch 5/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.4177 - accuracy: 0.7962 - val_loss: 0.4533 - val_accuracy: 0.7880
# Epoch 6/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.3995 - accuracy: 0.7987 - val_loss: 0.5863 - val_accuracy: 0.7080
# Epoch 7/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.3927 - accuracy: 0.8052 - val_loss: 0.5743 - val_accuracy: 0.7360
# 8/8 [==============================] - 1s 111ms/step - loss: 0.4533 - accuracy: 0.7880
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-11\assets
# --- Starting Trial: run-12
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 36s 1s/step - loss: 1.2715 - accuracy: 0.6439 - val_loss: 0.6807 - val_accuracy: 0.6320
# Epoch 2/15
# 32/32 [==============================] - 36s 1s/step - loss: 0.5427 - accuracy: 0.7343 - val_loss: 0.5337 - val_accuracy: 0.7280
# Epoch 3/15
# 32/32 [==============================] - 36s 1s/step - loss: 0.5765 - accuracy: 0.7033 - val_loss: 0.5731 - val_accuracy: 0.7120
# Epoch 4/15
# 32/32 [==============================] - 36s 1s/step - loss: 0.6247 - accuracy: 0.6209 - val_loss: 0.6243 - val_accuracy: 0.6200
# 8/8 [==============================] - 1s 116ms/step - loss: 0.5337 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-12\assets
# --- Starting Trial: run-13
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 48s 2s/step - loss: 1.0994 - accuracy: 0.6129 - val_loss: 0.5958 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.5348 - accuracy: 0.7343 - val_loss: 0.5420 - val_accuracy: 0.7120
# Epoch 3/15
# 32/32 [==============================] - 48s 1s/step - loss: 0.4666 - accuracy: 0.7647 - val_loss: 0.4826 - val_accuracy: 0.7760
# Epoch 4/15
# 32/32 [==============================] - 48s 2s/step - loss: 0.4225 - accuracy: 0.7882 - val_loss: 0.4685 - val_accuracy: 0.7400
# Epoch 5/15
# 32/32 [==============================] - 55s 2s/step - loss: 0.4038 - accuracy: 0.7947 - val_loss: 0.4992 - val_accuracy: 0.7400
# Epoch 6/15
# 32/32 [==============================] - 50s 2s/step - loss: 0.3832 - accuracy: 0.8112 - val_loss: 0.4375 - val_accuracy: 0.7880
# Epoch 7/15
# 32/32 [==============================] - 48s 1s/step - loss: 0.3285 - accuracy: 0.8367 - val_loss: 0.4140 - val_accuracy: 0.7920
# Epoch 8/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.3364 - accuracy: 0.8447 - val_loss: 0.4900 - val_accuracy: 0.7960
# Epoch 9/15
# 32/32 [==============================] - 48s 1s/step - loss: 0.3106 - accuracy: 0.8497 - val_loss: 0.4021 - val_accuracy: 0.8200
# Epoch 10/15
# 32/32 [==============================] - 48s 1s/step - loss: 0.2652 - accuracy: 0.8811 - val_loss: 0.3982 - val_accuracy: 0.8400
# Epoch 11/15
# 32/32 [==============================] - 48s 2s/step - loss: 0.2675 - accuracy: 0.8781 - val_loss: 0.4037 - val_accuracy: 0.8480
# Epoch 12/15
# 32/32 [==============================] - 57s 2s/step - loss: 0.2578 - accuracy: 0.8796 - val_loss: 0.4664 - val_accuracy: 0.8160
# 8/8 [==============================] - 2s 223ms/step - loss: 0.3982 - accuracy: 0.8400
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-13\assets
# --- Starting Trial: run-14
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 56s 2s/step - loss: 1.2339 - accuracy: 0.5729 - val_loss: 0.5948 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 [==============================] - 54s 2s/step - loss: 0.5386 - accuracy: 0.7507 - val_loss: 0.5082 - val_accuracy: 0.7840
# Epoch 3/15
# 32/32 [==============================] - 52s 2s/step - loss: 0.4578 - accuracy: 0.7727 - val_loss: 0.4704 - val_accuracy: 0.7640
# Epoch 4/15
# 32/32 [==============================] - 51s 2s/step - loss: 0.4514 - accuracy: 0.7762 - val_loss: 0.4728 - val_accuracy: 0.7680
# Epoch 5/15
# 32/32 [==============================] - 51s 2s/step - loss: 0.4438 - accuracy: 0.7802 - val_loss: 0.4664 - val_accuracy: 0.7360
# Epoch 6/15
# 32/32 [==============================] - 51s 2s/step - loss: 0.3990 - accuracy: 0.8002 - val_loss: 0.3841 - val_accuracy: 0.8280
# Epoch 7/15
# 32/32 [==============================] - 51s 2s/step - loss: 0.3752 - accuracy: 0.8187 - val_loss: 0.4672 - val_accuracy: 0.7880
# Epoch 8/15
# 32/32 [==============================] - 52s 2s/step - loss: 0.3440 - accuracy: 0.8377 - val_loss: 0.4021 - val_accuracy: 0.8240
# 8/8 [==============================] - 2s 286ms/step - loss: 0.3841 - accuracy: 0.8280
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-14\assets
# --- Starting Trial: run-15
# {'kernel size 1': 3, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 63s 2s/step - loss: 1.9124 - accuracy: 0.5954 - val_loss: 0.6226 - val_accuracy: 0.6440
# Epoch 2/15
# 32/32 [==============================] - 62s 2s/step - loss: 0.5716 - accuracy: 0.6973 - val_loss: 0.5435 - val_accuracy: 0.7240
# Epoch 3/15
# 32/32 [==============================] - 66s 2s/step - loss: 0.5198 - accuracy: 0.7348 - val_loss: 0.5078 - val_accuracy: 0.7640
# Epoch 4/15
# 32/32 [==============================] - 62s 2s/step - loss: 0.4522 - accuracy: 0.7757 - val_loss: 0.4670 - val_accuracy: 0.7760
# Epoch 5/15
# 32/32 [==============================] - 62s 2s/step - loss: 0.4430 - accuracy: 0.7802 - val_loss: 0.4983 - val_accuracy: 0.7280
# Epoch 6/15
# 32/32 [==============================] - 66s 2s/step - loss: 0.4082 - accuracy: 0.7922 - val_loss: 0.4475 - val_accuracy: 0.7680
# Epoch 7/15
# 32/32 [==============================] - 59s 2s/step - loss: 0.3637 - accuracy: 0.8352 - val_loss: 0.5169 - val_accuracy: 0.7440
# Epoch 8/15
# 32/32 [==============================] - 58s 2s/step - loss: 0.3410 - accuracy: 0.8397 - val_loss: 0.4264 - val_accuracy: 0.8120
# Epoch 9/15
# 32/32 [==============================] - 58s 2s/step - loss: 0.3029 - accuracy: 0.8686 - val_loss: 0.8833 - val_accuracy: 0.6960
# Epoch 10/15
# 32/32 [==============================] - 61s 2s/step - loss: 0.4639 - accuracy: 0.7942 - val_loss: 0.4315 - val_accuracy: 0.8320
# 8/8 [==============================] - 2s 197ms/step - loss: 0.4264 - accuracy: 0.8120
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-15\assets
# --- Starting Trial: run-16
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 83s 3s/step - loss: 1.2731 - accuracy: 0.6089 - val_loss: 0.6094 - val_accuracy: 0.6840
# Epoch 2/15
# 32/32 [==============================] - 86s 3s/step - loss: 0.5448 - accuracy: 0.7353 - val_loss: 0.5104 - val_accuracy: 0.7760
# Epoch 3/15
# 32/32 [==============================] - 83s 3s/step - loss: 0.4823 - accuracy: 0.7652 - val_loss: 0.4547 - val_accuracy: 0.8120
# Epoch 4/15
# 32/32 [==============================] - 81s 3s/step - loss: 0.4611 - accuracy: 0.7727 - val_loss: 0.5084 - val_accuracy: 0.7720
# Epoch 5/15
# 32/32 [==============================] - 79s 2s/step - loss: 0.4621 - accuracy: 0.7707 - val_loss: 0.5201 - val_accuracy: 0.7000
# 8/8 [==============================] - 2s 285ms/step - loss: 0.4547 - accuracy: 0.8120
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-16\assets
# --- Starting Trial: run-17
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 83s 3s/step - loss: 1.9582 - accuracy: 0.6094 - val_loss: 0.7380 - val_accuracy: 0.5720
# Epoch 2/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.5254 - accuracy: 0.7318 - val_loss: 0.7600 - val_accuracy: 0.6040
# Epoch 3/15
# 32/32 [==============================] - 86s 3s/step - loss: 0.5092 - accuracy: 0.7393 - val_loss: 0.4911 - val_accuracy: 0.7720
# Epoch 4/15
# 32/32 [==============================] - 87s 3s/step - loss: 0.4871 - accuracy: 0.7493 - val_loss: 0.5008 - val_accuracy: 0.7600
# Epoch 5/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4516 - accuracy: 0.7657 - val_loss: 0.5017 - val_accuracy: 0.7280
# 8/8 [==============================] - 2s 296ms/step - loss: 0.4911 - accuracy: 0.7720
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-17\assets
# --- Starting Trial: run-18
# {'kernel size 1': 3, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 87s 3s/step - loss: 1.9421 - accuracy: 0.5380 - val_loss: 0.6304 - val_accuracy: 0.7160
# Epoch 2/15
# 32/32 [==============================] - 109s 3s/step - loss: 0.5734 - accuracy: 0.7178 - val_loss: 0.6161 - val_accuracy: 0.7080
# Epoch 3/15
# 32/32 [==============================] - 99s 3s/step - loss: 0.5451 - accuracy: 0.7368 - val_loss: 0.5930 - val_accuracy: 0.6920
# Epoch 4/15
# 32/32 [==============================] - 99s 3s/step - loss: 0.4847 - accuracy: 0.7567 - val_loss: 0.4806 - val_accuracy: 0.7880
# Epoch 5/15
# 32/32 [==============================] - 98s 3s/step - loss: 0.4665 - accuracy: 0.7712 - val_loss: 0.4584 - val_accuracy: 0.8000
# Epoch 6/15
# 32/32 [==============================] - 98s 3s/step - loss: 0.4356 - accuracy: 0.7827 - val_loss: 0.4552 - val_accuracy: 0.7880
# Epoch 7/15
# 32/32 [==============================] - 95s 3s/step - loss: 0.4196 - accuracy: 0.7852 - val_loss: 0.4256 - val_accuracy: 0.8040
# Epoch 8/15
# 32/32 [==============================] - 95s 3s/step - loss: 0.4015 - accuracy: 0.8092 - val_loss: 0.4808 - val_accuracy: 0.7440
# Epoch 9/15
# 32/32 [==============================] - 97s 3s/step - loss: 0.3906 - accuracy: 0.8032 - val_loss: 0.5097 - val_accuracy: 0.7800
# 8/8 [==============================] - 3s 382ms/step - loss: 0.4256 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-18\assets
# --- Starting Trial: run-19
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 15s 470ms/step - loss: 0.8734 - accuracy: 0.6199 - val_loss: 0.5764 - val_accuracy: 0.6880
# Epoch 2/15
# 32/32 [==============================] - 15s 475ms/step - loss: 0.5429 - accuracy: 0.7178 - val_loss: 0.5410 - val_accuracy: 0.7840
# Epoch 3/15
# 32/32 [==============================] - 14s 450ms/step - loss: 0.4899 - accuracy: 0.7527 - val_loss: 0.4933 - val_accuracy: 0.7560
# Epoch 4/15
# 32/32 [==============================] - 15s 473ms/step - loss: 0.4612 - accuracy: 0.7722 - val_loss: 0.4942 - val_accuracy: 0.7400
# Epoch 5/15
# 32/32 [==============================] - 15s 468ms/step - loss: 0.4441 - accuracy: 0.7682 - val_loss: 0.5008 - val_accuracy: 0.7440
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4933 - accuracy: 0.7560
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-19\assets
# --- Starting Trial: run-20
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 17s 540ms/step - loss: 0.9089 - accuracy: 0.5984 - val_loss: 0.5668 - val_accuracy: 0.7480
# Epoch 2/15
# 32/32 [==============================] - 15s 467ms/step - loss: 0.5304 - accuracy: 0.7353 - val_loss: 0.5202 - val_accuracy: 0.7680
# Epoch 3/15
# 32/32 [==============================] - 16s 487ms/step - loss: 0.4808 - accuracy: 0.7567 - val_loss: 0.5280 - val_accuracy: 0.7600
# Epoch 4/15
# 32/32 [==============================] - 16s 501ms/step - loss: 0.4622 - accuracy: 0.7647 - val_loss: 0.5166 - val_accuracy: 0.7520
# Epoch 5/15
# 32/32 [==============================] - 15s 479ms/step - loss: 0.4289 - accuracy: 0.7822 - val_loss: 0.4536 - val_accuracy: 0.7760
# Epoch 6/15
# 32/32 [==============================] - 15s 455ms/step - loss: 0.4118 - accuracy: 0.8012 - val_loss: 0.4369 - val_accuracy: 0.7800
# Epoch 7/15
# 32/32 [==============================] - 16s 503ms/step - loss: 0.3983 - accuracy: 0.7957 - val_loss: 0.4174 - val_accuracy: 0.8080
# Epoch 8/15
# 32/32 [==============================] - 15s 471ms/step - loss: 0.3706 - accuracy: 0.8252 - val_loss: 0.4186 - val_accuracy: 0.8120
# Epoch 9/15
# 32/32 [==============================] - 15s 460ms/step - loss: 0.3767 - accuracy: 0.8177 - val_loss: 0.4382 - val_accuracy: 0.8000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4174 - accuracy: 0.8080
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-20\assets
# --- Starting Trial: run-21
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 32, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 17s 520ms/step - loss: 1.1183 - accuracy: 0.6324 - val_loss: 0.5989 - val_accuracy: 0.6680
# Epoch 2/15
# 32/32 [==============================] - 18s 564ms/step - loss: 0.5231 - accuracy: 0.7298 - val_loss: 0.5129 - val_accuracy: 0.7720
# Epoch 3/15
# 32/32 [==============================] - 16s 504ms/step - loss: 0.4863 - accuracy: 0.7562 - val_loss: 0.4802 - val_accuracy: 0.7560
# Epoch 4/15
# 32/32 [==============================] - 16s 513ms/step - loss: 0.4705 - accuracy: 0.7617 - val_loss: 0.4673 - val_accuracy: 0.7760
# Epoch 5/15
# 32/32 [==============================] - 18s 548ms/step - loss: 0.4417 - accuracy: 0.7687 - val_loss: 0.5785 - val_accuracy: 0.7440
# Epoch 6/15
# 32/32 [==============================] - 17s 537ms/step - loss: 0.4228 - accuracy: 0.7872 - val_loss: 0.4516 - val_accuracy: 0.7600
# Epoch 7/15
# 32/32 [==============================] - 18s 549ms/step - loss: 0.4036 - accuracy: 0.7887 - val_loss: 0.4211 - val_accuracy: 0.7800
# Epoch 8/15
# 32/32 [==============================] - 17s 516ms/step - loss: 0.5599 - accuracy: 0.7353 - val_loss: 0.5195 - val_accuracy: 0.7000
# Epoch 9/15
# 32/32 [==============================] - 16s 503ms/step - loss: 0.4894 - accuracy: 0.7463 - val_loss: 0.4976 - val_accuracy: 0.7200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4211 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-21\assets
# --- Starting Trial: run-22
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 18s 577ms/step - loss: 0.9997 - accuracy: 0.5709 - val_loss: 0.5902 - val_accuracy: 0.7320
# Epoch 2/15
# 32/32 [==============================] - 18s 570ms/step - loss: 0.5673 - accuracy: 0.7088 - val_loss: 0.5686 - val_accuracy: 0.6920
# Epoch 3/15
# 32/32 [==============================] - 18s 561ms/step - loss: 0.5193 - accuracy: 0.7383 - val_loss: 0.5225 - val_accuracy: 0.7320
# Epoch 4/15
# 32/32 [==============================] - 18s 570ms/step - loss: 0.4791 - accuracy: 0.7692 - val_loss: 0.5239 - val_accuracy: 0.7200
# Epoch 5/15
# 32/32 [==============================] - 19s 607ms/step - loss: 0.4544 - accuracy: 0.7692 - val_loss: 0.4868 - val_accuracy: 0.7640
# Epoch 6/15
# 32/32 [==============================] - 19s 578ms/step - loss: 0.4565 - accuracy: 0.7707 - val_loss: 0.4787 - val_accuracy: 0.7560
# Epoch 7/15
# 32/32 [==============================] - 20s 617ms/step - loss: 0.4366 - accuracy: 0.7837 - val_loss: 0.4587 - val_accuracy: 0.7760
# Epoch 8/15
# 32/32 [==============================] - 18s 566ms/step - loss: 0.4167 - accuracy: 0.7942 - val_loss: 0.4567 - val_accuracy: 0.7800
# Epoch 9/15
# 32/32 [==============================] - 18s 570ms/step - loss: 0.4106 - accuracy: 0.8012 - val_loss: 0.5698 - val_accuracy: 0.7080
# Epoch 10/15
# 32/32 [==============================] - 18s 565ms/step - loss: 0.4249 - accuracy: 0.7807 - val_loss: 0.5156 - val_accuracy: 0.7440
# 8/8 [==============================] - 0s 57ms/step - loss: 0.4567 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-22\assets
# --- Starting Trial: run-23
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 19s 598ms/step - loss: 0.9897 - accuracy: 0.6209 - val_loss: 0.5822 - val_accuracy: 0.7240
# Epoch 2/15
# 32/32 [==============================] - 19s 585ms/step - loss: 0.5050 - accuracy: 0.7507 - val_loss: 0.5105 - val_accuracy: 0.7800
# Epoch 3/15
# 32/32 [==============================] - 19s 598ms/step - loss: 0.4641 - accuracy: 0.7622 - val_loss: 0.6061 - val_accuracy: 0.7040
# Epoch 4/15
# 32/32 [==============================] - 20s 614ms/step - loss: 0.5004 - accuracy: 0.7353 - val_loss: 0.5515 - val_accuracy: 0.6840
# 8/8 [==============================] - 1s 64ms/step - loss: 0.5105 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-23\assets
# --- Starting Trial: run-24
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 32, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 22s 683ms/step - loss: 1.1726 - accuracy: 0.5754 - val_loss: 0.5981 - val_accuracy: 0.6840
# Epoch 2/15
# 32/32 [==============================] - 21s 670ms/step - loss: 0.5820 - accuracy: 0.6803 - val_loss: 0.5593 - val_accuracy: 0.7480
# Epoch 3/15
# 32/32 [==============================] - 20s 640ms/step - loss: 0.5399 - accuracy: 0.7188 - val_loss: 0.5745 - val_accuracy: 0.7200
# Epoch 4/15
# 32/32 [==============================] - 20s 635ms/step - loss: 0.4973 - accuracy: 0.7463 - val_loss: 0.5139 - val_accuracy: 0.7520
# Epoch 5/15
# 32/32 [==============================] - 20s 638ms/step - loss: 0.5057 - accuracy: 0.7443 - val_loss: 0.5729 - val_accuracy: 0.6960
# Epoch 6/15
# 32/32 [==============================] - 20s 639ms/step - loss: 0.4796 - accuracy: 0.7478 - val_loss: 0.8549 - val_accuracy: 0.6600
# 8/8 [==============================] - 1s 63ms/step - loss: 0.5139 - accuracy: 0.7520
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-24\assets
# --- Starting Trial: run-25
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 24s 762ms/step - loss: 0.9803 - accuracy: 0.6119 - val_loss: 0.6167 - val_accuracy: 0.6440
# Epoch 2/15
# 32/32 [==============================] - 24s 747ms/step - loss: 0.5477 - accuracy: 0.7168 - val_loss: 0.5750 - val_accuracy: 0.7440
# Epoch 3/15
# 32/32 [==============================] - 24s 751ms/step - loss: 0.5164 - accuracy: 0.7233 - val_loss: 0.5158 - val_accuracy: 0.7800
# Epoch 4/15
# 32/32 [==============================] - 24s 752ms/step - loss: 0.4955 - accuracy: 0.7448 - val_loss: 0.4859 - val_accuracy: 0.7200
# Epoch 5/15
# 32/32 [==============================] - 24s 752ms/step - loss: 0.4695 - accuracy: 0.7647 - val_loss: 0.4652 - val_accuracy: 0.8040
# Epoch 6/15
# 32/32 [==============================] - 24s 744ms/step - loss: 0.4370 - accuracy: 0.7832 - val_loss: 0.5096 - val_accuracy: 0.7200
# Epoch 7/15
# 32/32 [==============================] - 24s 746ms/step - loss: 0.4562 - accuracy: 0.7642 - val_loss: 0.4778 - val_accuracy: 0.7560
# 8/8 [==============================] - 1s 86ms/step - loss: 0.4652 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-25\assets
# --- Starting Trial: run-26
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 26s 809ms/step - loss: 1.1115 - accuracy: 0.6039 - val_loss: 0.6002 - val_accuracy: 0.7160
# Epoch 2/15
# 32/32 [==============================] - 25s 790ms/step - loss: 0.5691 - accuracy: 0.7238 - val_loss: 0.5637 - val_accuracy: 0.7240
# Epoch 3/15
# 32/32 [==============================] - 26s 803ms/step - loss: 0.5269 - accuracy: 0.7308 - val_loss: 0.7629 - val_accuracy: 0.6400
# Epoch 4/15
# 32/32 [==============================] - 25s 784ms/step - loss: 0.4960 - accuracy: 0.7552 - val_loss: 0.4826 - val_accuracy: 0.7640
# Epoch 5/15
# 32/32 [==============================] - 25s 794ms/step - loss: 0.4828 - accuracy: 0.7597 - val_loss: 0.4946 - val_accuracy: 0.7400
# Epoch 6/15
# 32/32 [==============================] - 26s 816ms/step - loss: 0.4828 - accuracy: 0.7502 - val_loss: 0.4799 - val_accuracy: 0.7320
# Epoch 7/15
# 32/32 [==============================] - 25s 783ms/step - loss: 0.4664 - accuracy: 0.7637 - val_loss: 0.5555 - val_accuracy: 0.7280
# Epoch 8/15
# 32/32 [==============================] - 25s 790ms/step - loss: 0.4826 - accuracy: 0.7448 - val_loss: 0.4958 - val_accuracy: 0.7520
# 8/8 [==============================] - 1s 91ms/step - loss: 0.4799 - accuracy: 0.7320
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-26\assets
# --- Starting Trial: run-27
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 64, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 28s 888ms/step - loss: 0.9695 - accuracy: 0.6533 - val_loss: 0.5549 - val_accuracy: 0.7640
# Epoch 2/15
# 32/32 [==============================] - 28s 883ms/step - loss: 0.5365 - accuracy: 0.7283 - val_loss: 0.5340 - val_accuracy: 0.7480
# Epoch 3/15
# 32/32 [==============================] - 29s 904ms/step - loss: 0.4980 - accuracy: 0.7542 - val_loss: 0.5779 - val_accuracy: 0.6760
# Epoch 4/15
# 32/32 [==============================] - 29s 897ms/step - loss: 0.4759 - accuracy: 0.7522 - val_loss: 0.4764 - val_accuracy: 0.7680
# Epoch 5/15
# 32/32 [==============================] - 29s 891ms/step - loss: 0.4374 - accuracy: 0.7857 - val_loss: 0.4576 - val_accuracy: 0.7960
# Epoch 6/15
# 32/32 [==============================] - 28s 877ms/step - loss: 0.4276 - accuracy: 0.7792 - val_loss: 0.4618 - val_accuracy: 0.7640
# Epoch 7/15
# 32/32 [==============================] - 28s 889ms/step - loss: 0.3925 - accuracy: 0.8067 - val_loss: 0.4579 - val_accuracy: 0.7480
# 8/8 [==============================] - 1s 101ms/step - loss: 0.4576 - accuracy: 0.7960
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-27\assets
# --- Starting Trial: run-28
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 33s 1s/step - loss: 1.0573 - accuracy: 0.6039 - val_loss: 0.5614 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.5483 - accuracy: 0.7173 - val_loss: 0.5611 - val_accuracy: 0.6720
# Epoch 3/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.5256 - accuracy: 0.7293 - val_loss: 0.5020 - val_accuracy: 0.7640
# Epoch 4/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.5015 - accuracy: 0.7343 - val_loss: 0.5196 - val_accuracy: 0.7240
# Epoch 5/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.4961 - accuracy: 0.7413 - val_loss: 0.5209 - val_accuracy: 0.7280
# 8/8 [==============================] - 1s 115ms/step - loss: 0.5020 - accuracy: 0.7640
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-28\assets
# --- Starting Trial: run-29
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 35s 1s/step - loss: 1.2388 - accuracy: 0.5455 - val_loss: 0.6484 - val_accuracy: 0.6280
# Epoch 2/15
# 32/32 [==============================] - 36s 1s/step - loss: 0.5896 - accuracy: 0.6783 - val_loss: 0.5673 - val_accuracy: 0.7000
# Epoch 3/15
# 32/32 [==============================] - 37s 1s/step - loss: 0.5406 - accuracy: 0.7233 - val_loss: 0.5410 - val_accuracy: 0.7000
# Epoch 4/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4938 - accuracy: 0.7498 - val_loss: 0.5321 - val_accuracy: 0.7240
# Epoch 5/15
# 32/32 [==============================] - 33s 1s/step - loss: 0.4881 - accuracy: 0.7433 - val_loss: 0.5377 - val_accuracy: 0.6840
# Epoch 6/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4950 - accuracy: 0.7502 - val_loss: 0.5158 - val_accuracy: 0.7280
# Epoch 7/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4892 - accuracy: 0.7517 - val_loss: 0.5054 - val_accuracy: 0.7320
# Epoch 8/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4756 - accuracy: 0.7488 - val_loss: 0.4854 - val_accuracy: 0.7840
# Epoch 9/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4499 - accuracy: 0.7632 - val_loss: 0.5350 - val_accuracy: 0.7720
# Epoch 10/15
# 32/32 [==============================] - 32s 1s/step - loss: 0.4476 - accuracy: 0.7802 - val_loss: 0.5738 - val_accuracy: 0.7400
# 8/8 [==============================] - 1s 116ms/step - loss: 0.4854 - accuracy: 0.7840
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-29\assets
# --- Starting Trial: run-30
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 64, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 35s 1s/step - loss: 1.7776 - accuracy: 0.5834 - val_loss: 0.5838 - val_accuracy: 0.6960
# Epoch 2/15
# 32/32 [==============================] - 35s 1s/step - loss: 0.5488 - accuracy: 0.7293 - val_loss: 0.5315 - val_accuracy: 0.7400
# Epoch 3/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.5506 - accuracy: 0.7303 - val_loss: 0.5398 - val_accuracy: 0.7440
# Epoch 4/15
# 32/32 [==============================] - 34s 1s/step - loss: 0.4957 - accuracy: 0.7522 - val_loss: 0.5319 - val_accuracy: 0.7080
# 8/8 [==============================] - 1s 144ms/step - loss: 0.5315 - accuracy: 0.7400
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-30\assets
# --- Starting Trial: run-31
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 48s 1s/step - loss: 1.2293 - accuracy: 0.5964 - val_loss: 0.5981 - val_accuracy: 0.7160
# Epoch 2/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.6222 - accuracy: 0.6833 - val_loss: 0.5903 - val_accuracy: 0.7120
# Epoch 3/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.5542 - accuracy: 0.7293 - val_loss: 0.5681 - val_accuracy: 0.7440
# Epoch 4/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.5378 - accuracy: 0.7223 - val_loss: 0.5824 - val_accuracy: 0.6960
# Epoch 5/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4849 - accuracy: 0.7502 - val_loss: 0.5460 - val_accuracy: 0.7320
# Epoch 6/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4668 - accuracy: 0.7712 - val_loss: 0.5164 - val_accuracy: 0.7560
# Epoch 7/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4717 - accuracy: 0.7627 - val_loss: 0.4960 - val_accuracy: 0.7360
# Epoch 8/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4526 - accuracy: 0.7682 - val_loss: 0.4804 - val_accuracy: 0.7320
# Epoch 9/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4869 - accuracy: 0.7602 - val_loss: 0.4843 - val_accuracy: 0.7480
# Epoch 10/15
# 32/32 [==============================] - 46s 1s/step - loss: 0.4328 - accuracy: 0.7802 - val_loss: 0.4719 - val_accuracy: 0.7640
# Epoch 11/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4256 - accuracy: 0.7872 - val_loss: 0.5094 - val_accuracy: 0.7680
# Epoch 12/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4326 - accuracy: 0.7782 - val_loss: 0.4651 - val_accuracy: 0.7560
# Epoch 13/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4029 - accuracy: 0.7932 - val_loss: 0.4523 - val_accuracy: 0.7680
# Epoch 14/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4367 - accuracy: 0.7767 - val_loss: 0.5075 - val_accuracy: 0.7560
# Epoch 15/15
# 32/32 [==============================] - 47s 1s/step - loss: 0.4068 - accuracy: 0.7842 - val_loss: 0.4511 - val_accuracy: 0.7800
# 8/8 [==============================] - 1s 182ms/step - loss: 0.4511 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-31\assets
# --- Starting Trial: run-32
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 50s 2s/step - loss: 1.7403 - accuracy: 0.5305 - val_loss: 0.6875 - val_accuracy: 0.5160
# Epoch 2/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.6431 - accuracy: 0.6319 - val_loss: 0.5929 - val_accuracy: 0.6920
# Epoch 3/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.5848 - accuracy: 0.6928 - val_loss: 0.5556 - val_accuracy: 0.7280
# Epoch 4/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.5453 - accuracy: 0.7243 - val_loss: 0.5188 - val_accuracy: 0.7680
# Epoch 5/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.5063 - accuracy: 0.7522 - val_loss: 0.5238 - val_accuracy: 0.7160
# Epoch 6/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.4970 - accuracy: 0.7562 - val_loss: 0.5017 - val_accuracy: 0.7280
# Epoch 7/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.4846 - accuracy: 0.7552 - val_loss: 0.6523 - val_accuracy: 0.6720
# Epoch 8/15
# 32/32 [==============================] - 49s 2s/step - loss: 0.4615 - accuracy: 0.7727 - val_loss: 0.5034 - val_accuracy: 0.7720
# 8/8 [==============================] - 1s 187ms/step - loss: 0.5017 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-32\assets
# --- Starting Trial: run-33
# {'kernel size 1': 7, 'kernel size 2': 3, 'kernel num': 128, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 55s 2s/step - loss: 2.6605 - accuracy: 0.5584 - val_loss: 0.6474 - val_accuracy: 0.5920
# Epoch 2/15
# 32/32 [==============================] - 55s 2s/step - loss: 0.5906 - accuracy: 0.7098 - val_loss: 0.6182 - val_accuracy: 0.6640
# Epoch 3/15
# 32/32 [==============================] - 55s 2s/step - loss: 0.5393 - accuracy: 0.7258 - val_loss: 0.5127 - val_accuracy: 0.7680
# Epoch 4/15
# 32/32 [==============================] - 55s 2s/step - loss: 0.5150 - accuracy: 0.7328 - val_loss: 0.5322 - val_accuracy: 0.7360
# Epoch 5/15
# 32/32 [==============================] - 55s 2s/step - loss: 0.4850 - accuracy: 0.7393 - val_loss: 0.5534 - val_accuracy: 0.7240
# 8/8 [==============================] - 2s 203ms/step - loss: 0.5127 - accuracy: 0.7680
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-33\assets
# --- Starting Trial: run-34
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 256}
# Epoch 1/15
# 32/32 [==============================] - 74s 2s/step - loss: 1.7369 - accuracy: 0.5440 - val_loss: 0.6689 - val_accuracy: 0.5640
# Epoch 2/15
# 32/32 [==============================] - 75s 2s/step - loss: 0.5797 - accuracy: 0.6928 - val_loss: 0.5734 - val_accuracy: 0.7600
# Epoch 3/15
# 32/32 [==============================] - 75s 2s/step - loss: 0.5283 - accuracy: 0.7308 - val_loss: 0.5524 - val_accuracy: 0.7080
# Epoch 4/15
# 32/32 [==============================] - 74s 2s/step - loss: 0.4951 - accuracy: 0.7552 - val_loss: 0.4892 - val_accuracy: 0.7920
# Epoch 5/15
# 32/32 [==============================] - 93s 3s/step - loss: 0.4709 - accuracy: 0.7682 - val_loss: 0.5160 - val_accuracy: 0.7480
# Epoch 6/15
# 32/32 [==============================] - 88s 3s/step - loss: 0.4635 - accuracy: 0.7577 - val_loss: 0.4981 - val_accuracy: 0.7280
# 8/8 [==============================] - 3s 325ms/step - loss: 0.4892 - accuracy: 0.7920
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-34\assets
# --- Starting Trial: run-35
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 512}
# Epoch 1/15
# 32/32 [==============================] - 80s 3s/step - loss: 1.5490 - accuracy: 0.5155 - val_loss: 0.6663 - val_accuracy: 0.5120
# Epoch 2/15
# 32/32 [==============================] - 80s 3s/step - loss: 0.6060 - accuracy: 0.6973 - val_loss: 0.5781 - val_accuracy: 0.7160
# Epoch 3/15
# 32/32 [==============================] - 84s 3s/step - loss: 0.5513 - accuracy: 0.7283 - val_loss: 0.5361 - val_accuracy: 0.7200
# Epoch 4/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.5083 - accuracy: 0.7517 - val_loss: 0.5446 - val_accuracy: 0.7640
# Epoch 5/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4954 - accuracy: 0.7448 - val_loss: 0.4939 - val_accuracy: 0.7640
# Epoch 6/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4746 - accuracy: 0.7647 - val_loss: 0.4753 - val_accuracy: 0.7720
# Epoch 7/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4574 - accuracy: 0.7762 - val_loss: 0.5005 - val_accuracy: 0.7520
# Epoch 8/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4874 - accuracy: 0.7542 - val_loss: 0.4673 - val_accuracy: 0.7600
# Epoch 9/15
# 32/32 [==============================] - 83s 3s/step - loss: 0.4255 - accuracy: 0.7937 - val_loss: 0.4514 - val_accuracy: 0.7960
# Epoch 10/15
# 32/32 [==============================] - 82s 3s/step - loss: 0.4030 - accuracy: 0.8122 - val_loss: 0.4620 - val_accuracy: 0.7720
# Epoch 11/15
# 32/32 [==============================] - 83s 3s/step - loss: 0.3979 - accuracy: 0.8027 - val_loss: 0.4410 - val_accuracy: 0.7920
# Epoch 12/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.3928 - accuracy: 0.8047 - val_loss: 0.5106 - val_accuracy: 0.7720
# Epoch 13/15
# 32/32 [==============================] - 84s 3s/step - loss: 0.4004 - accuracy: 0.7977 - val_loss: 0.4622 - val_accuracy: 0.7720
# 8/8 [==============================] - 3s 326ms/step - loss: 0.4410 - accuracy: 0.7920
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-35\assets
# --- Starting Trial: run-36
# {'kernel size 1': 7, 'kernel size 2': 5, 'kernel num': 128, 'dense size': 1024}
# Epoch 1/15
# 32/32 [==============================] - 90s 3s/step - loss: 2.7368 - accuracy: 0.5455 - val_loss: 0.7736 - val_accuracy: 0.4920
# Epoch 2/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.6325 - accuracy: 0.6598 - val_loss: 0.5763 - val_accuracy: 0.7280
# Epoch 3/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.5452 - accuracy: 0.7223 - val_loss: 0.5547 - val_accuracy: 0.7240
# Epoch 4/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.5171 - accuracy: 0.7423 - val_loss: 0.5481 - val_accuracy: 0.7280
# Epoch 5/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.4994 - accuracy: 0.7473 - val_loss: 0.5449 - val_accuracy: 0.7320
# Epoch 6/15
# 32/32 [==============================] - 89s 3s/step - loss: 0.4911 - accuracy: 0.7512 - val_loss: 0.5144 - val_accuracy: 0.7600
# Epoch 7/15
# 32/32 [==============================] - 91s 3s/step - loss: 0.4795 - accuracy: 0.7552 - val_loss: 0.5169 - val_accuracy: 0.7840
# Epoch 8/15
# 32/32 [==============================] - 102s 3s/step - loss: 0.4802 - accuracy: 0.7592 - val_loss: 0.5299 - val_accuracy: 0.7240
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5144 - accuracy: 0.7600
# INFO:tensorflow:Assets written to: saved_models\Model 1 (Trousers&Jeans_Female)\Run-36\assets
